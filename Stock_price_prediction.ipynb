# %% [markdown]
# <a href="https://colab.research.google.com/github/JayatriPati/Stock-price-prediction/blob/main/Stock_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prediction of close price of stock for Reliance Industries from 2012 to 2023
#
# ---

# %%
from google.colab import drive

path='/content/drive/MyDrive/Colab Notebooks/500325 (3).csv'

import pandas as pd

df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#            Date  Open Price  High Price  Low Price  Close Price          WAP  \
# 0   3-July-2023     2553.20     2622.00    2553.20      2615.20  2594.171088
# 1  30-June-2023     2540.05     2556.70    2533.00      2550.70  2542.410839
# 2  28-June-2023     2516.00     2537.25    2497.70      2529.35  2525.107662
# 3  27-June-2023     2501.00     2510.00    2486.40      2495.80  2495.111112
# 4  26-June-2023     2504.00     2515.90    2489.25      2494.20  2499.732812
# 5  23-June-2023     2530.00     2532.80    2511.10      2515.25  2521.028400
# 6  22-June-2023     2561.70     2572.90    2532.25      2535.60  2552.037861
# 7  21-June-2023     2556.35     2569.10    2547.95      2563.60  2560.359581
# 8  20-June-2023     2550.50     2564.00    2535.00      2546.75  2545.358236
# 9  19-June-2023     2582.20     2584.00    2543.40      2551.50  2552.289896
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# ...

# %%
df.shape
# Out:
# (2723, 13)

# %%
df.columns
# Out:
# Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2723 entries, 0 to 2722
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2723 non-null   object
#  1   Open Price                 2723 non-null   float64
#  2   High Price                 2723 non-null   float64
#  3   Low Price                  2723 non-null   float64
#  4   Close Price                2723 non-null   float64
#  5   WAP                        2723 non-null   float64
#  6   No.of Shares               2723 non-null   int64
#  7   No. of Trades              2723 non-null   int64
#  8   Total Turnover (Rs.)       2723 non-null   float64
#  9   Deliverable Quantity       2715 non-null   float64
#  10  % Deli. Qty to Traded Qty  2715 non-null   float64
#  11  Spread High-Low            2723 non-null   float64
#  12  Spread Close-Open          2723 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         8
# % Deli. Qty to Traded Qty    8
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
df = df.dropna()

# %%
df=df.drop(['Date'],axis=1)

# %%
df
# Out:
#       Open Price  High Price  Low Price  Close Price          WAP  \
# 0        2553.20     2622.00    2553.20      2615.20  2594.171088
# 1        2540.05     2556.70    2533.00      2550.70  2542.410839
# 2        2516.00     2537.25    2497.70      2529.35  2525.107662
# 3        2501.00     2510.00    2486.40      2495.80  2495.111112
# 4        2504.00     2515.90    2489.25      2494.20  2499.732812
# ...          ...         ...        ...          ...          ...
# 2718      739.00      739.00     729.65       734.30   733.170387
# 2719      735.90      742.20     731.80       738.50   738.409602
# 2720      739.00      740.00     729.05       734.05   733.321532
# 2721      740.75      742.90     731.30       736.00   737.241692
# 2722      736.10      740.95     730.60       737.45   735.930791
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0           517214          35468          1.341742e+09              350871.0
# ...

# %%
df.isnull().sum()
# Out:
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
features = ['Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
       'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
       'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
       'Spread Close-Open']

plt.subplots(figsize=(7,5))

for i, col in enumerate(features):
  plt.subplot(4,3,i+1)
  sns.distplot(df[col])
plt.show()


import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close Price'])
plt.title('Relaince Close price.', fontsize=15)
plt.ylabel('Price in INR')
plt.show()

# %%
plt.subplots(figsize=(10,10))
for i, col in enumerate(features):
  plt.subplot(4,3,i+1)
  sns.boxplot(df[col])
plt.show()

# %%
plt.figure(figsize=(10, 10))

sns.heatmap(df.corr()>0.9,fmt = '.2f', annot=True, cbar=False)
plt.show()

# %%
features = df[['Open Price', 'High Price', 'Low Price','WAP']]
target = df['Close Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

scaler = StandardScaler()
features = scaler.fit_transform(features)
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.1, random_state=42)

# %%
from xgboost import XGBRegressor
model=XGBRegressor()
model.fit(X_train, Y_train)
Y_pred=model.predict(X_test)
